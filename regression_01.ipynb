# %% [markdown]
# <a href="https://colab.research.google.com/github/FarhanFansuri/Tensorflow-2024/blob/regression/regression_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
